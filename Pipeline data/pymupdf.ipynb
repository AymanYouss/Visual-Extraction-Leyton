# %%
import fitz  # PyMuPDF
from PIL import Image
import io

# Define the path to your PDF file
pdf_path = 'cv.pdf'

# Open the PDF
doc = fitz.open(pdf_path)

# List to hold each page's image
pdf_images = []

# Extract images from each page
for page_num in range(len(doc)):
    page = doc.load_page(page_num)  # Load the current page
    pix = page.get_pixmap()  # Render page to an image
    img = Image.open(io.BytesIO(pix.tobytes()))  # Convert the image to a PIL Image
    pdf_images.append(img)

# %%
# Load the image file
image_path = 'image.png'
image = Image.open(image_path)

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = "C:/Program Files/Tesseract-OCR/tesseract.exe"  # your path may be different

# Function to apply OCR on an image
def extract_text_from_image(img):
    text = pytesseract.image_to_string(img, lang='eng')  # You can change 'eng' to the appropriate language if needed
    return text

# Extract text from the standalone image
image_text = extract_text_from_image(image)

# Extract text from each PDF page image
pdf_texts = [extract_text_from_image(img) for img in pdf_images]

# %%
# Function to analyze visual components of each PDF page
def analyze_visual_components(page):
    # Extract images
    image_list = page.get_images(full=True)
    # Extract drawings (lines, rectangles, etc.)
    drawings = page.get_drawings()

    # This is a simplistic representation. You might need to expand this according to your needs.
    visuals = {
        'images-length': len(image_list),
        'drawings-length': len(drawings),
        'images': image_list,
        'drawings' : drawings
    }
    return visuals

# Analyze each page in the PDF
pdf_visuals = [analyze_visual_components(doc.load_page(i)) for i in range(len(doc))]

# %%
# Function to print and understand drawings from a PDF page
def print_drawings(drawings):
    for i, drawing in enumerate(drawings):
        print(f"Drawing {i + 1}:")
        for key, value in drawing.items():
            # Simplify the printing of complex structures like points
            if isinstance(value, list) and all(isinstance(item, (list, tuple)) for item in value):
                print(f"  {key}: [")
                for point in value:
                    print(f"    {point},")
                print("  ]")
            else:
                print(f"  {key}: {value}")
        print("")  # Add an empty line for better separation between drawings

# Example usage:
# Assuming pdf_visuals is a list of visuals from each page as in your provided code
for i, visuals in enumerate(pdf_visuals):
    print(f"Page {i + 1}:")
    print_drawings(visuals['drawings'])
# Out:
# Page 1:
# Drawing 1:
#   items: [
#     ('re', Rect(0.0, 0.0, 187.34255981445312, 841.542724609375), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.27059999108314514, 0.34119999408721924, 0.40779998898506165)
#   rect: Rect(0.0, 0.0, 187.34255981445312, 841.542724609375)
#   seqno: 0
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 2:
#   items: [
#     ('re', Rect(0.0, 0.0, 187.34255981445312, 100.41561126708984), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.8549000024795532, 0.6470999717712402, 0.0)
#   rect: Rect(0.0, 0.0, 187.34255981445312, 100.41561126708984)
#   seqno: 22
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 3:
#   items: [
#     ('l', Point(29.974807739257812, 343.2115478515625), Point(29.974807739257812, 342.4621887207031)),
#     ('c', Point(29.974807739257812, 342.4621887207031), Point(29.97480583190918, 342.263427734375), Point(30.012834548950195, 342.0722351074219), Point(30.08888816833496, 341.88861083984375)),
#     ('c', Point(30.08888816833496, 341.88861083984375), Point(30.16494369506836, 341.7049865722656), Point(30.27324104309082, 341.5429382324219), Point(30.41377830505371, 341.40240478515625)),
#     ('c', Point(30.41377830505371, 341.40240478515625), Point(30.554311752319336, 341.2618408203125), Point(30.71638298034668, 341.1535339355469), Point(30.900001525878906, 341.0774841308594)),
#     ('c', Point(30.900001525878906, 341.0774841308594), Point(31.0836181640625, 341.00146484375), Point(31.27480125427246, 340.96343994140625), Point(31.473548889160156, 340.96343994140625)),
#     ('l', Point(31.473548889160156, 340.96343994140625), Point(142.38034057617188, 340.96343994140625)),
#     ('c', Point(142.38034057617188, 340.96343994140625), Point(142.57908630371094, 340.96343994140625), Point(142.770263671875, 341.00146484375), Point(142.95387268066406, 341.0774841308594)),
#     ('c', Point(142.95387268066406, 341.0774841308594), Point(143.13748168945312, 341.1535339355469), Point(143.299560546875, 341.2618408203125), Point(143.44009399414062, 341.40240478515625)),
#     ('c', Point(143.44009399414062, 341.40240478515625), Point(143.58062744140625, 341.5429382324219), Point(143.6889190673828, 341.7049865722656), Point(143.76498413085938, 341.88861083984375)),
#     ('c', Point(143.76498413085938, 341.88861083984375), Point(143.84103393554688, 342.0722351074219), Point(143.8790740966797, 342.263427734375), Point(143.87908935546875, 342.4621887207031)),
#     ('l', Point(143.87908935546875, 342.4621887207031), Point(143.87908935546875, 343.2115478515625)),
#     ('c', Point(143.87908935546875, 343.2115478515625), Point(143.8790740966797, 343.4102783203125), Point(143.84103393554688, 343.6014404296875), Point(143.76498413085938, 343.7850646972656)),
#     ('c', Point(143.76498413085938, 343.7850646972656), Point(143.6889190673828, 343.96868896484375), Point(143.58062744140625, 344.1307678222656), Point(143.44009399414062, 344.27130126953125)),
#     ('c', Point(143.44009399414062, 344.27130126953125), Point(143.299560546875, 344.41180419921875), Point(143.13748168945312, 344.5201110839844), Point(142.95387268066406, 344.5961608886719)),
#     ('c', Point(142.95387268066406, 344.5961608886719), Point(142.770263671875, 344.6722106933594), Point(142.57908630371094, 344.71026611328125), Point(142.38034057617188, 344.7102966308594)),
#     ('l', Point(142.38034057617188, 344.7102966308594), Point(31.473548889160156, 344.7102966308594)),
#     ('c', Point(31.473548889160156, 344.7102966308594), Point(31.27480125427246, 344.71026611328125), Point(31.0836181640625, 344.6722106933594), Point(30.900001525878906, 344.5961608886719)),
#     ('c', Point(30.900001525878906, 344.5961608886719), Point(30.71638298034668, 344.5201110839844), Point(30.554311752319336, 344.41180419921875), Point(30.41377830505371, 344.27130126953125)),
#     ('c', Point(30.41377830505371, 344.27130126953125), Point(30.27324104309082, 344.1307678222656), Point(30.16494369506836, 343.96868896484375), Point(30.08888816833496, 343.7850341796875)),
#     ('c', Point(30.08888816833496, 343.7850341796875), Point(30.012834548950195, 343.6014404296875), Point(29.97480583190918, 343.4102783203125), Point(29.974807739257812, 343.2115478515625)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 0.3019999861717224
#   fill: (0.6078000068664551, 0.6078000068664551, 0.6078000068664551)
#   rect: Rect(29.97480583190918, 340.96343994140625, 143.87908935546875, 344.7102966308594)
#   seqno: 29
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 4:
#   items: [
#     ('l', Point(29.974807739257812, 343.2115478515625), Point(29.974807739257812, 342.4621887207031)),
#     ('c', Point(29.974807739257812, 342.4621887207031), Point(29.97480583190918, 342.263427734375), Point(30.012834548950195, 342.0722351074219), Point(30.08888816833496, 341.88861083984375)),
#     ('c', Point(30.08888816833496, 341.88861083984375), Point(30.16494369506836, 341.7049865722656), Point(30.27324104309082, 341.5429382324219), Point(30.41377830505371, 341.40240478515625)),
#     ('c', Point(30.41377830505371, 341.40240478515625), Point(30.554311752319336, 341.2618408203125), Point(30.71638298034668, 341.1535339355469), Point(30.900001525878906, 341.0774841308594)),
#     ('c', Point(30.900001525878906, 341.0774841308594), Point(31.0836181640625, 341.00146484375), Point(31.27480125427246, 340.96343994140625), Point(31.473548889160156, 340.96343994140625)),
#     ('l', Point(31.473548889160156, 340.96343994140625), Point(142.38034057617188, 340.96343994140625)),
#     ('c', Point(142.38034057617188, 340.96343994140625), Point(142.57908630371094, 340.96343994140625), Point(142.770263671875, 341.00146484375), Point(142.95387268066406, 341.0774841308594)),
#     ('c', Point(142.95387268066406, 341.0774841308594), Point(143.13748168945312, 341.1535339355469), Point(143.299560546875, 341.2618408203125), Point(143.44009399414062, 341.40240478515625)),
#     ('c', Point(143.44009399414062, 341.40240478515625), Point(143.58062744140625, 341.5429382324219), Point(143.6889190673828, 341.7049865722656), Point(143.76498413085938, 341.88861083984375)),
#     ('c', Point(143.76498413085938, 341.88861083984375), Point(143.84103393554688, 342.0722351074219), Point(143.8790740966797, 342.263427734375), Point(143.87908935546875, 342.4621887207031)),
#     ('l', Point(143.87908935546875, 342.4621887207031), Point(143.87908935546875, 343.2115478515625)),
#     ('c', Point(143.87908935546875, 343.2115478515625), Point(143.8790740966797, 343.4102783203125), Point(143.84103393554688, 343.6014404296875), Point(143.76498413085938, 343.7850646972656)),
#     ('c', Point(143.76498413085938, 343.7850646972656), Point(143.6889190673828, 343.96868896484375), Point(143.58062744140625, 344.1307678222656), Point(143.44009399414062, 344.27130126953125)),
#     ('c', Point(143.44009399414062, 344.27130126953125), Point(143.299560546875, 344.41180419921875), Point(143.13748168945312, 344.5201110839844), Point(142.95387268066406, 344.5961608886719)),
#     ('c', Point(142.95387268066406, 344.5961608886719), Point(142.770263671875, 344.6722106933594), Point(142.57908630371094, 344.71026611328125), Point(142.38034057617188, 344.7102966308594)),
#     ('l', Point(142.38034057617188, 344.7102966308594), Point(31.473548889160156, 344.7102966308594)),
#     ('c', Point(31.473548889160156, 344.7102966308594), Point(31.27480125427246, 344.71026611328125), Point(31.0836181640625, 344.6722106933594), Point(30.900001525878906, 344.5961608886719)),
#     ('c', Point(30.900001525878906, 344.5961608886719), Point(30.71638298034668, 344.5201110839844), Point(30.554311752319336, 344.41180419921875), Point(30.41377830505371, 344.27130126953125)),
#     ('c', Point(30.41377830505371, 344.27130126953125), Point(30.27324104309082, 344.1307678222656), Point(30.16494369506836, 343.96868896484375), Point(30.08888816833496, 343.7850341796875)),
#     ('c', Point(30.08888816833496, 343.7850341796875), Point(30.012834548950195, 343.6014404296875), Point(29.97480583190918, 343.4102783203125), Point(29.974807739257812, 343.2115478515625)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.8549000024795532, 0.6470999717712402, 0.0)
#   rect: Rect(29.97480583190918, 340.96343994140625, 143.87908935546875, 344.7102966308594)
#   seqno: 30
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 5:
#   items: [
#     ('l', Point(29.974807739257812, 377.6825866699219), Point(29.974807739257812, 376.9332275390625)),
#     ('c', Point(29.974807739257812, 376.9332275390625), Point(29.97480583190918, 376.7344665527344), Point(30.012834548950195, 376.5432434082031), Point(30.08888816833496, 376.359619140625)),
#     ('c', Point(30.08888816833496, 376.359619140625), Point(30.16494369506836, 376.1759948730469), Point(30.27324104309082, 376.0139465332031), Point(30.41377830505371, 375.8734130859375)),
#     ('c', Point(30.41377830505371, 375.8734130859375), Point(30.554311752319336, 375.7328796386719), Point(30.71638298034668, 375.62457275390625), Point(30.900001525878906, 375.5484924316406)),
#     ('c', Point(30.900001525878906, 375.5484924316406), Point(31.0836181640625, 375.47247314453125), Point(31.27480125427246, 375.4344787597656), Point(31.473548889160156, 375.4344787597656)),
#     ('l', Point(31.473548889160156, 375.4344787597656), Point(142.38034057617188, 375.4344787597656)),
#     ('c', Point(142.38034057617188, 375.4344787597656), Point(142.57908630371094, 375.4344787597656), Point(142.770263671875, 375.47247314453125), Point(142.95387268066406, 375.5484924316406)),
#     ('c', Point(142.95387268066406, 375.5484924316406), Point(143.13748168945312, 375.62457275390625), Point(143.299560546875, 375.7328796386719), Point(143.44009399414062, 375.8734130859375)),
#     ('c', Point(143.44009399414062, 375.8734130859375), Point(143.58062744140625, 376.0139465332031), Point(143.6889190673828, 376.1759948730469), Point(143.76498413085938, 376.359619140625)),
#     ('c', Point(143.76498413085938, 376.359619140625), Point(143.84103393554688, 376.5432434082031), Point(143.8790740966797, 376.7344665527344), Point(143.87908935546875, 376.9332275390625)),
#     ('l', Point(143.87908935546875, 376.9332275390625), Point(143.87908935546875, 377.6825866699219)),
#     ('c', Point(143.87908935546875, 377.6825866699219), Point(143.8790740966797, 377.88128662109375), Point(143.84103393554688, 378.0724792480469), Point(143.76498413085938, 378.256103515625)),
#     ('c', Point(143.76498413085938, 378.256103515625), Point(143.6889190673828, 378.439697265625), Point(143.58062744140625, 378.6017761230469), Point(143.44009399414062, 378.7423400878906)),
#     ('c', Point(143.44009399414062, 378.7423400878906), Point(143.299560546875, 378.88287353515625), Point(143.13748168945312, 378.99114990234375), Point(142.95387268066406, 379.06719970703125)),
#     ('c', Point(142.95387268066406, 379.06719970703125), Point(142.770263671875, 379.14324951171875), Point(142.57908630371094, 379.1813049316406), Point(142.38034057617188, 379.18133544921875)),
#     ('l', Point(142.38034057617188, 379.18133544921875), Point(31.473548889160156, 379.18133544921875)),
#     ('c', Point(31.473548889160156, 379.18133544921875), Point(31.27480125427246, 379.1813049316406), Point(31.0836181640625, 379.14324951171875), Point(30.900001525878906, 379.06719970703125)),
#     ('c', Point(30.900001525878906, 379.06719970703125), Point(30.71638298034668, 378.99114990234375), Point(30.554311752319336, 378.88287353515625), Point(30.41377830505371, 378.7423400878906)),
#     ('c', Point(30.41377830505371, 378.7423400878906), Point(30.27324104309082, 378.6017761230469), Point(30.16494369506836, 378.439697265625), Point(30.08888816833496, 378.256103515625)),
#     ('c', Point(30.08888816833496, 378.256103515625), Point(30.012834548950195, 378.0724792480469), Point(29.97480583190918, 377.88128662109375), Point(29.974807739257812, 377.6825866699219)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 0.3019999861717224
#   fill: (0.6078000068664551, 0.6078000068664551, 0.6078000068664551)
#   rect: Rect(29.97480583190918, 375.4344787597656, 143.87908935546875, 379.18133544921875)
#   seqno: 31
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 6:
#   items: [
#     ('l', Point(29.974807739257812, 377.6825866699219), Point(29.974807739257812, 376.9332275390625)),
#     ('c', Point(29.974807739257812, 376.9332275390625), Point(29.97480583190918, 376.7344665527344), Point(30.012834548950195, 376.5432434082031), Point(30.08888816833496, 376.359619140625)),
#     ('c', Point(30.08888816833496, 376.359619140625), Point(30.16494369506836, 376.1759948730469), Point(30.27324104309082, 376.0139465332031), Point(30.41377830505371, 375.8734130859375)),
#     ('c', Point(30.41377830505371, 375.8734130859375), Point(30.554311752319336, 375.7328796386719), Point(30.71638298034668, 375.62457275390625), Point(30.900001525878906, 375.5484924316406)),
#     ('c', Point(30.900001525878906, 375.5484924316406), Point(31.0836181640625, 375.47247314453125), Point(31.27480125427246, 375.4344787597656), Point(31.473548889160156, 375.4344787597656)),
#     ('l', Point(31.473548889160156, 375.4344787597656), Point(142.38034057617188, 375.4344787597656)),
#     ('c', Point(142.38034057617188, 375.4344787597656), Point(142.57908630371094, 375.4344787597656), Point(142.770263671875, 375.47247314453125), Point(142.95387268066406, 375.5484924316406)),
#     ('c', Point(142.95387268066406, 375.5484924316406), Point(143.13748168945312, 375.62457275390625), Point(143.299560546875, 375.7328796386719), Point(143.44009399414062, 375.8734130859375)),
#     ('c', Point(143.44009399414062, 375.8734130859375), Point(143.58062744140625, 376.0139465332031), Point(143.6889190673828, 376.1759948730469), Point(143.76498413085938, 376.359619140625)),
#     ('c', Point(143.76498413085938, 376.359619140625), Point(143.84103393554688, 376.5432434082031), Point(143.8790740966797, 376.7344665527344), Point(143.87908935546875, 376.9332275390625)),
#     ('l', Point(143.87908935546875, 376.9332275390625), Point(143.87908935546875, 377.6825866699219)),
#     ('c', Point(143.87908935546875, 377.6825866699219), Point(143.8790740966797, 377.88128662109375), Point(143.84103393554688, 378.0724792480469), Point(143.76498413085938, 378.256103515625)),
#     ('c', Point(143.76498413085938, 378.256103515625), Point(143.6889190673828, 378.439697265625), Point(143.58062744140625, 378.6017761230469), Point(143.44009399414062, 378.7423400878906)),
#     ('c', Point(143.44009399414062, 378.7423400878906), Point(143.299560546875, 378.88287353515625), Point(143.13748168945312, 378.99114990234375), Point(142.95387268066406, 379.06719970703125)),
#     ('c', Point(142.95387268066406, 379.06719970703125), Point(142.770263671875, 379.14324951171875), Point(142.57908630371094, 379.1813049316406), Point(142.38034057617188, 379.18133544921875)),
#     ('l', Point(142.38034057617188, 379.18133544921875), Point(31.473548889160156, 379.18133544921875)),
#     ('c', Point(31.473548889160156, 379.18133544921875), Point(31.27480125427246, 379.1813049316406), Point(31.0836181640625, 379.14324951171875), Point(30.900001525878906, 379.06719970703125)),
#     ('c', Point(30.900001525878906, 379.06719970703125), Point(30.71638298034668, 378.99114990234375), Point(30.554311752319336, 378.88287353515625), Point(30.41377830505371, 378.7423400878906)),
#     ('c', Point(30.41377830505371, 378.7423400878906), Point(30.27324104309082, 378.6017761230469), Point(30.16494369506836, 378.439697265625), Point(30.08888816833496, 378.256103515625)),
#     ('c', Point(30.08888816833496, 378.256103515625), Point(30.012834548950195, 378.0724792480469), Point(29.97480583190918, 377.88128662109375), Point(29.974807739257812, 377.6825866699219)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.8549000024795532, 0.6470999717712402, 0.0)
#   rect: Rect(29.97480583190918, 375.4344787597656, 143.87908935546875, 379.18133544921875)
#   seqno: 32
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 7:
#   items: [
#     ('l', Point(29.974807739257812, 412.15362548828125), Point(29.974807739257812, 411.40423583984375)),
#     ('c', Point(29.974807739257812, 411.40423583984375), Point(29.97480583190918, 411.20550537109375), Point(30.012834548950195, 411.01434326171875), Point(30.08888816833496, 410.8306884765625)),
#     ('c', Point(30.08888816833496, 410.8306884765625), Point(30.16494369506836, 410.6470642089844), Point(30.27324104309082, 410.4850158691406), Point(30.41377830505371, 410.3444519042969)),
#     ('c', Point(30.41377830505371, 410.3444519042969), Point(30.554311752319336, 410.2038879394531), Point(30.71638298034668, 410.09564208984375), Point(30.900001525878906, 410.01959228515625)),
#     ('c', Point(30.900001525878906, 410.01959228515625), Point(31.0836181640625, 409.9435119628906), Point(31.27480125427246, 409.905517578125), Point(31.473548889160156, 409.905517578125)),
#     ('l', Point(31.473548889160156, 409.905517578125), Point(142.38034057617188, 409.905517578125)),
#     ('c', Point(142.38034057617188, 409.905517578125), Point(142.57908630371094, 409.905517578125), Point(142.770263671875, 409.9435119628906), Point(142.95387268066406, 410.01959228515625)),
#     ('c', Point(142.95387268066406, 410.01959228515625), Point(143.13748168945312, 410.09564208984375), Point(143.299560546875, 410.2038879394531), Point(143.44009399414062, 410.3444519042969)),
#     ('c', Point(143.44009399414062, 410.3444519042969), Point(143.58062744140625, 410.4850158691406), Point(143.6889190673828, 410.6470642089844), Point(143.76498413085938, 410.8306884765625)),
#     ('c', Point(143.76498413085938, 410.8306884765625), Point(143.84103393554688, 411.01434326171875), Point(143.8790740966797, 411.20550537109375), Point(143.87908935546875, 411.40423583984375)),
#     ('l', Point(143.87908935546875, 411.40423583984375), Point(143.87908935546875, 412.15362548828125)),
#     ('c', Point(143.87908935546875, 412.15362548828125), Point(143.8790740966797, 412.35235595703125), Point(143.84103393554688, 412.5434875488281), Point(143.76498413085938, 412.7271423339844)),
#     ('c', Point(143.76498413085938, 412.7271423339844), Point(143.6889190673828, 412.91070556640625), Point(143.58062744140625, 413.07281494140625), Point(143.44009399414062, 413.21337890625)),
#     ('c', Point(143.44009399414062, 413.21337890625), Point(143.299560546875, 413.3538818359375), Point(143.13748168945312, 413.4621887207031), Point(142.95387268066406, 413.5382385253906)),
#     ('c', Point(142.95387268066406, 413.5382385253906), Point(142.770263671875, 413.61431884765625), Point(142.57908630371094, 413.6523132324219), Point(142.38034057617188, 413.6523742675781)),
#     ('l', Point(142.38034057617188, 413.6523742675781), Point(31.473548889160156, 413.6523742675781)),
#     ('c', Point(31.473548889160156, 413.6523742675781), Point(31.27480125427246, 413.6523132324219), Point(31.0836181640625, 413.6142578125), Point(30.900001525878906, 413.5382080078125)),
#     ('c', Point(30.900001525878906, 413.5382080078125), Point(30.71638298034668, 413.4621276855469), Point(30.554311752319336, 413.3538818359375), Point(30.41377830505371, 413.21337890625)),
#     ('c', Point(30.41377830505371, 413.21337890625), Point(30.27324104309082, 413.07281494140625), Point(30.16494369506836, 412.91070556640625), Point(30.08888816833496, 412.7271423339844)),
#     ('c', Point(30.08888816833496, 412.7271423339844), Point(30.012834548950195, 412.5434875488281), Point(29.97480583190918, 412.35235595703125), Point(29.974807739257812, 412.15362548828125)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 0.3019999861717224
#   fill: (0.6078000068664551, 0.6078000068664551, 0.6078000068664551)
#   rect: Rect(29.97480583190918, 409.905517578125, 143.87908935546875, 413.6523742675781)
#   seqno: 33
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 8:
#   items: [
#     ('l', Point(29.974807739257812, 412.15362548828125), Point(29.974807739257812, 411.40423583984375)),
#     ('c', Point(29.974807739257812, 411.40423583984375), Point(29.97480583190918, 411.20550537109375), Point(30.012834548950195, 411.01434326171875), Point(30.08888816833496, 410.8306884765625)),
#     ('c', Point(30.08888816833496, 410.8306884765625), Point(30.16494369506836, 410.6470642089844), Point(30.27324104309082, 410.4850158691406), Point(30.41377830505371, 410.3444519042969)),
#     ('c', Point(30.41377830505371, 410.3444519042969), Point(30.554311752319336, 410.2038879394531), Point(30.71638298034668, 410.09564208984375), Point(30.900001525878906, 410.01959228515625)),
#     ('c', Point(30.900001525878906, 410.01959228515625), Point(31.0836181640625, 409.9435119628906), Point(31.27480125427246, 409.905517578125), Point(31.473548889160156, 409.905517578125)),
#     ('l', Point(31.473548889160156, 409.905517578125), Point(142.38034057617188, 409.905517578125)),
#     ('c', Point(142.38034057617188, 409.905517578125), Point(142.57908630371094, 409.905517578125), Point(142.770263671875, 409.9435119628906), Point(142.95387268066406, 410.01959228515625)),
#     ('c', Point(142.95387268066406, 410.01959228515625), Point(143.13748168945312, 410.09564208984375), Point(143.299560546875, 410.2038879394531), Point(143.44009399414062, 410.3444519042969)),
#     ('c', Point(143.44009399414062, 410.3444519042969), Point(143.58062744140625, 410.4850158691406), Point(143.6889190673828, 410.6470642089844), Point(143.76498413085938, 410.8306884765625)),
#     ('c', Point(143.76498413085938, 410.8306884765625), Point(143.84103393554688, 411.01434326171875), Point(143.8790740966797, 411.20550537109375), Point(143.87908935546875, 411.40423583984375)),
#     ('l', Point(143.87908935546875, 411.40423583984375), Point(143.87908935546875, 412.15362548828125)),
#     ('c', Point(143.87908935546875, 412.15362548828125), Point(143.8790740966797, 412.35235595703125), Point(143.84103393554688, 412.5434875488281), Point(143.76498413085938, 412.7271423339844)),
#     ('c', Point(143.76498413085938, 412.7271423339844), Point(143.6889190673828, 412.91070556640625), Point(143.58062744140625, 413.07281494140625), Point(143.44009399414062, 413.21337890625)),
#     ('c', Point(143.44009399414062, 413.21337890625), Point(143.299560546875, 413.3538818359375), Point(143.13748168945312, 413.4621887207031), Point(142.95387268066406, 413.5382385253906)),
#     ('c', Point(142.95387268066406, 413.5382385253906), Point(142.770263671875, 413.61431884765625), Point(142.57908630371094, 413.6523132324219), Point(142.38034057617188, 413.6523742675781)),
#     ('l', Point(142.38034057617188, 413.6523742675781), Point(31.473548889160156, 413.6523742675781)),
#     ('c', Point(31.473548889160156, 413.6523742675781), Point(31.27480125427246, 413.6523132324219), Point(31.0836181640625, 413.6142578125), Point(30.900001525878906, 413.5382080078125)),
#     ('c', Point(30.900001525878906, 413.5382080078125), Point(30.71638298034668, 413.4621276855469), Point(30.554311752319336, 413.3538818359375), Point(30.41377830505371, 413.21337890625)),
#     ('c', Point(30.41377830505371, 413.21337890625), Point(30.27324104309082, 413.07281494140625), Point(30.16494369506836, 412.91070556640625), Point(30.08888816833496, 412.7271423339844)),
#     ('c', Point(30.08888816833496, 412.7271423339844), Point(30.012834548950195, 412.5434875488281), Point(29.97480583190918, 412.35235595703125), Point(29.974807739257812, 412.15362548828125)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.8549000024795532, 0.6470999717712402, 0.0)
#   rect: Rect(29.97480583190918, 409.905517578125, 143.87908935546875, 413.6523742675781)
#   seqno: 34
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 9:
#   items: [
#     ('re', Rect(29.974807739257812, 29.974807739257812, 187.34255981445312, 201.58058166503906), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (1.0, 1.0, 1.0)
#   rect: Rect(29.974807739257812, 29.974807739257812, 187.34255981445312, 201.58058166503906)
#   seqno: 39
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 10:
#   items: [
#     ('re', Rect(217.31736755371094, 75.68639373779297, 565.025146484375, 76.43576049804688), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.8666999936103821, 0.8666999936103821, 0.8666999936103821)
#   rect: Rect(217.31736755371094, 75.68639373779297, 565.025146484375, 76.43576049804688)
#   seqno: 41
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 11:
#   items: [
#     ('re', Rect(217.31736755371094, 140.13223266601562, 565.025146484375, 140.88160705566406), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.8666999936103821, 0.8666999936103821, 0.8666999936103821)
#   rect: Rect(217.31736755371094, 140.13223266601562, 565.025146484375, 140.88160705566406)
#   seqno: 42
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 12:
#   items: [
#     ('re', Rect(221.064208984375, 194.08688354492188, 221.81358337402344, 370.9382629394531), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.0, 0.0, 0.0)
#   rect: Rect(221.064208984375, 194.08688354492188, 221.81358337402344, 370.9382629394531)
#   seqno: 53
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 13:
#   items: [
#     ('re', Rect(236.80099487304688, 199.3324737548828, 278.7657165527344, 220.31484985351562), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.27059999108314514, 0.34119999408721924, 0.40779998898506165)
#   rect: Rect(236.80099487304688, 199.3324737548828, 278.7657165527344, 220.31484985351562)
#   seqno: 54
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 14:
#   items: [
#     ('c', Point(243.54531860351562, 245.4187469482422), Point(243.54530334472656, 245.66714477539062), Point(243.4977569580078, 245.90611267089844), Point(243.40267944335938, 246.1356201171875)),
#     ('c', Point(243.40267944335938, 246.1356201171875), Point(243.3076171875, 246.36512756347656), Point(243.1722412109375, 246.56773376464844), Point(242.99658203125, 246.74342346191406)),
#     ('c', Point(242.99658203125, 246.74342346191406), Point(242.8209228515625, 246.91908264160156), Point(242.6183319091797, 247.054443359375), Point(242.38880920410156, 247.1495361328125)),
#     ('c', Point(242.38880920410156, 247.1495361328125), Point(242.15927124023438, 247.24459838867188), Point(241.92031860351562, 247.29214477539062), Point(241.67189025878906, 247.29217529296875)),
#     ('c', Point(241.67189025878906, 247.29217529296875), Point(241.42344665527344, 247.29214477539062), Point(241.18446350097656, 247.24459838867188), Point(240.95492553710938, 247.1495361328125)),
#     ('c', Point(240.95492553710938, 247.1495361328125), Point(240.7254180908203, 247.054443359375), Point(240.5228271484375, 246.91908264160156), Point(240.34716796875, 246.74342346191406)),
#     ('c', Point(240.34716796875, 246.74342346191406), Point(240.17147827148438, 246.56773376464844), Point(240.03610229492188, 246.36512756347656), Point(239.9410400390625, 246.1356201171875)),
#     ('c', Point(239.9410400390625, 246.1356201171875), Point(239.84596252441406, 245.90611267089844), Point(239.79844665527344, 245.66714477539062), Point(239.7984619140625, 245.4187469482422)),
#     ('c', Point(239.7984619140625, 245.4187469482422), Point(239.79844665527344, 245.17030334472656), Point(239.84596252441406, 244.9313201904297), Point(239.9410400390625, 244.7017822265625)),
#     ('c', Point(239.9410400390625, 244.7017822265625), Point(240.03610229492188, 244.47227478027344), Point(240.17147827148438, 244.26966857910156), Point(240.34716796875, 244.09400939941406)),
#     ('c', Point(240.34716796875, 244.09400939941406), Point(240.5228271484375, 243.9183349609375), Point(240.7254180908203, 243.78297424316406), Point(240.95492553710938, 243.6879119873047)),
#     ('c', Point(240.95492553710938, 243.6879119873047), Point(241.18446350097656, 243.5928497314453), Point(241.42344665527344, 243.54531860351562), Point(241.67189025878906, 243.54531860351562)),
#     ('c', Point(241.67189025878906, 243.54531860351562), Point(241.92031860351562, 243.54531860351562), Point(242.15927124023438, 243.5928497314453), Point(242.38880920410156, 243.6879119873047)),
#     ('c', Point(242.38880920410156, 243.6879119873047), Point(242.6183319091797, 243.78297424316406), Point(242.8209228515625, 243.9183349609375), Point(242.99658203125, 244.09400939941406)),
#     ('c', Point(242.99658203125, 244.09400939941406), Point(243.1722412109375, 244.26966857910156), Point(243.3076171875, 244.47227478027344), Point(243.40267944335938, 244.7017822265625)),
#     ('c', Point(243.40267944335938, 244.7017822265625), Point(243.4977569580078, 244.9313201904297), Point(243.54530334472656, 245.17030334472656), Point(243.54531860351562, 245.4187469482422)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.26669999957084656, 0.26669999957084656, 0.26669999957084656)
#   rect: Rect(239.79844665527344, 243.54531860351562, 243.54531860351562, 247.29217529296875)
#   seqno: 59
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 15:
#   items: [
#     ('c', Point(243.54531860351562, 284.385986328125), Point(243.54530334472656, 284.6343994140625), Point(243.4977569580078, 284.87335205078125), Point(243.40267944335938, 285.1028747558594)),
#     ('c', Point(243.40267944335938, 285.1028747558594), Point(243.3076171875, 285.3323974609375), Point(243.1722412109375, 285.53497314453125), Point(242.99658203125, 285.710693359375)),
#     ('c', Point(242.99658203125, 285.710693359375), Point(242.8209228515625, 285.8863525390625), Point(242.6183319091797, 286.0216979980469), Point(242.38880920410156, 286.11676025390625)),
#     ('c', Point(242.38880920410156, 286.11676025390625), Point(242.15927124023438, 286.2118225097656), Point(241.92031860351562, 286.2593994140625), Point(241.67189025878906, 286.2594299316406)),
#     ('c', Point(241.67189025878906, 286.2594299316406), Point(241.42344665527344, 286.2593994140625), Point(241.18446350097656, 286.2118225097656), Point(240.95492553710938, 286.11676025390625)),
#     ('c', Point(240.95492553710938, 286.11676025390625), Point(240.7254180908203, 286.0216979980469), Point(240.5228271484375, 285.8863525390625), Point(240.34716796875, 285.710693359375)),
#     ('c', Point(240.34716796875, 285.710693359375), Point(240.17147827148438, 285.53497314453125), Point(240.03610229492188, 285.3323974609375), Point(239.9410400390625, 285.1028747558594)),
#     ('c', Point(239.9410400390625, 285.1028747558594), Point(239.84596252441406, 284.87335205078125), Point(239.79844665527344, 284.6343994140625), Point(239.7984619140625, 284.385986328125)),
#     ('c', Point(239.7984619140625, 284.385986328125), Point(239.79844665527344, 284.13751220703125), Point(239.84596252441406, 283.8985595703125), Point(239.9410400390625, 283.66900634765625)),
#     ('c', Point(239.9410400390625, 283.66900634765625), Point(240.03610229492188, 283.4394836425781), Point(240.17147827148438, 283.2369079589844), Point(240.34716796875, 283.0612487792969)),
#     ('c', Point(240.34716796875, 283.0612487792969), Point(240.5228271484375, 282.8855895996094), Point(240.7254180908203, 282.7502136230469), Point(240.95492553710938, 282.6551513671875)),
#     ('c', Point(240.95492553710938, 282.6551513671875), Point(241.18446350097656, 282.5600891113281), Point(241.42344665527344, 282.5125732421875), Point(241.67189025878906, 282.5125732421875)),
#     ('c', Point(241.67189025878906, 282.5125732421875), Point(241.92031860351562, 282.5125732421875), Point(242.15927124023438, 282.5600891113281), Point(242.38880920410156, 282.6551513671875)),
#     ('c', Point(242.38880920410156, 282.6551513671875), Point(242.6183319091797, 282.7502136230469), Point(242.8209228515625, 282.8855895996094), Point(242.99658203125, 283.0612487792969)),
#     ('c', Point(242.99658203125, 283.0612487792969), Point(243.1722412109375, 283.2369079589844), Point(243.3076171875, 283.4394836425781), Point(243.40267944335938, 283.66900634765625)),
#     ('c', Point(243.40267944335938, 283.66900634765625), Point(243.4977569580078, 283.8985595703125), Point(243.54530334472656, 284.13751220703125), Point(243.54531860351562, 284.385986328125)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.26669999957084656, 0.26669999957084656, 0.26669999957084656)
#   rect: Rect(239.79844665527344, 282.5125732421875, 243.54531860351562, 286.2594299316406)
#   seqno: 64
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 16:
#   items: [
#     ('c', Point(243.54531860351562, 323.3532409667969), Point(243.54530334472656, 323.6016845703125), Point(243.4977569580078, 323.84063720703125), Point(243.40267944335938, 324.07012939453125)),
#     ('c', Point(243.40267944335938, 324.07012939453125), Point(243.3076171875, 324.29962158203125), Point(243.1722412109375, 324.5022277832031), Point(242.99658203125, 324.6779479980469)),
#     ('c', Point(242.99658203125, 324.6779479980469), Point(242.8209228515625, 324.85357666015625), Point(242.6183319091797, 324.9889831542969), Point(242.38880920410156, 325.08404541015625)),
#     ('c', Point(242.38880920410156, 325.08404541015625), Point(242.15927124023438, 325.1791076660156), Point(241.92031860351562, 325.2266540527344), Point(241.67189025878906, 325.2266845703125)),
#     ('c', Point(241.67189025878906, 325.2266845703125), Point(241.42344665527344, 325.2266540527344), Point(241.18446350097656, 325.1791076660156), Point(240.95492553710938, 325.08404541015625)),
#     ('c', Point(240.95492553710938, 325.08404541015625), Point(240.7254180908203, 324.9889831542969), Point(240.5228271484375, 324.85357666015625), Point(240.34716796875, 324.6779479980469)),
#     ('c', Point(240.34716796875, 324.6779479980469), Point(240.17147827148438, 324.5022277832031), Point(240.03610229492188, 324.29962158203125), Point(239.9410400390625, 324.07012939453125)),
#     ('c', Point(239.9410400390625, 324.07012939453125), Point(239.84596252441406, 323.84063720703125), Point(239.79844665527344, 323.6016845703125), Point(239.7984619140625, 323.3532409667969)),
#     ('c', Point(239.7984619140625, 323.3532409667969), Point(239.79844665527344, 323.1047668457031), Point(239.84596252441406, 322.86578369140625), Point(239.9410400390625, 322.6362609863281)),
#     ('c', Point(239.9410400390625, 322.6362609863281), Point(240.03610229492188, 322.40673828125), Point(240.17147827148438, 322.20416259765625), Point(240.34716796875, 322.02850341796875)),
#     ('c', Point(240.34716796875, 322.02850341796875), Point(240.5228271484375, 321.85284423828125), Point(240.7254180908203, 321.71746826171875), Point(240.95492553710938, 321.6224060058594)),
#     ('c', Point(240.95492553710938, 321.6224060058594), Point(241.18446350097656, 321.52734375), Point(241.42344665527344, 321.4798278808594), Point(241.67189025878906, 321.4798278808594)),
#     ('c', Point(241.67189025878906, 321.4798278808594), Point(241.92031860351562, 321.4798278808594), Point(242.15927124023438, 321.52734375), Point(242.38880920410156, 321.6224060058594)),
#     ('c', Point(242.38880920410156, 321.6224060058594), Point(242.6183319091797, 321.71746826171875), Point(242.8209228515625, 321.85284423828125), Point(242.99658203125, 322.02850341796875)),
#     ('c', Point(242.99658203125, 322.02850341796875), Point(243.1722412109375, 322.20416259765625), Point(243.3076171875, 322.40673828125), Point(243.40267944335938, 322.63629150390625)),
#     ('c', Point(243.40267944335938, 322.63629150390625), Point(243.4977569580078, 322.86578369140625), Point(243.54530334472656, 323.1047668457031), Point(243.54531860351562, 323.3532409667969)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.26669999957084656, 0.26669999957084656, 0.26669999957084656)
#   rect: Rect(239.79844665527344, 321.4798278808594, 243.54531860351562, 325.2266845703125)
#   seqno: 69
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 17:
#   items: [
#     ('c', Point(224.0616912841797, 208.32492065429688), Point(224.06167602539062, 208.722412109375), Point(223.98561096191406, 209.10475158691406), Point(223.83351135253906, 209.47198486328125)),
#     ('c', Point(223.83351135253906, 209.47198486328125), Point(223.68138122558594, 209.83921813964844), Point(223.4647979736328, 210.16336059570312), Point(223.18373107910156, 210.44444274902344)),
#     ('c', Point(223.18373107910156, 210.44444274902344), Point(222.90264892578125, 210.72549438476562), Point(222.57847595214844, 210.9420928955078), Point(222.21127319335938, 211.0941925048828)),
#     ('c', Point(222.21127319335938, 211.0941925048828), Point(221.8440399169922, 211.24632263183594), Point(221.46170043945312, 211.32237243652344), Point(221.064208984375, 211.32240295410156)),
#     ('c', Point(221.064208984375, 211.32240295410156), Point(220.66668701171875, 211.32237243652344), Point(220.28431701660156, 211.24632263183594), Point(219.9171142578125, 211.0941925048828)),
#     ('c', Point(219.9171142578125, 211.0941925048828), Point(219.5498504638672, 210.9420928955078), Point(219.2257080078125, 210.72549438476562), Point(218.9446563720703, 210.44444274902344)),
#     ('c', Point(218.9446563720703, 210.44444274902344), Point(218.66358947753906, 210.16336059570312), Point(218.44699096679688, 209.83921813964844), Point(218.2948760986328, 209.47198486328125)),
#     ('c', Point(218.2948760986328, 209.47198486328125), Point(218.1427764892578, 209.10475158691406), Point(218.06671142578125, 208.722412109375), Point(218.0667266845703, 208.32492065429688)),
#     ('c', Point(218.0667266845703, 208.32492065429688), Point(218.06671142578125, 207.92742919921875), Point(218.1427764892578, 207.54505920410156), Point(218.2948760986328, 207.1778106689453)),
#     ('c', Point(218.2948760986328, 207.1778106689453), Point(218.44699096679688, 206.81056213378906), Point(218.66358947753906, 206.48641967773438), Point(218.9446563720703, 206.20535278320312)),
#     ('c', Point(218.9446563720703, 206.20535278320312), Point(219.2257080078125, 205.92430114746094), Point(219.5498504638672, 205.70770263671875), Point(219.9171142578125, 205.5555877685547)),
#     ('c', Point(219.9171142578125, 205.5555877685547), Point(220.28431701660156, 205.40347290039062), Point(220.66668701171875, 205.3274383544922), Point(221.064208984375, 205.3274383544922)),
#     ('c', Point(221.064208984375, 205.3274383544922), Point(221.46170043945312, 205.3274383544922), Point(221.8440399169922, 205.40347290039062), Point(222.21127319335938, 205.5555877685547)),
#     ('c', Point(222.21127319335938, 205.5555877685547), Point(222.57847595214844, 205.70770263671875), Point(222.90264892578125, 205.92430114746094), Point(223.18373107910156, 206.20535278320312)),
#     ('c', Point(223.18373107910156, 206.20535278320312), Point(223.4647979736328, 206.48641967773438), Point(223.68138122558594, 206.81056213378906), Point(223.83351135253906, 207.1778106689453)),
#     ('c', Point(223.83351135253906, 207.1778106689453), Point(223.98561096191406, 207.54505920410156), Point(224.06167602539062, 207.92742919921875), Point(224.0616912841797, 208.32492065429688)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.06669999659061432, 0.06669999659061432, 0.06669999659061432)
#   rect: Rect(218.06671142578125, 205.3274383544922, 224.0616912841797, 211.32240295410156)
#   seqno: 75
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 18:
#   items: [
#     ('re', Rect(221.064208984375, 370.9382629394531, 221.81358337402344, 434.6347351074219), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.0, 0.0, 0.0)
#   rect: Rect(221.064208984375, 370.9382629394531, 221.81358337402344, 434.6347351074219)
#   seqno: 76
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 19:
#   items: [
#     ('re', Rect(236.80099487304688, 382.1788024902344, 313.9861145019531, 403.1611633300781), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.27059999108314514, 0.34119999408721924, 0.40779998898506165)
#   rect: Rect(236.80099487304688, 382.1788024902344, 313.9861145019531, 403.1611633300781)
#   seqno: 77
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 20:
#   items: [
#     ('c', Point(224.0616912841797, 391.1712646484375), Point(224.06167602539062, 391.5687255859375), Point(223.98561096191406, 391.9510498046875), Point(223.83351135253906, 392.3182678222656)),
#     ('c', Point(223.83351135253906, 392.3182678222656), Point(223.68138122558594, 392.68548583984375), Point(223.4647979736328, 393.0096435546875), Point(223.18373107910156, 393.2907409667969)),
#     ('c', Point(223.18373107910156, 393.2907409667969), Point(222.90264892578125, 393.5718078613281), Point(222.57847595214844, 393.7884216308594), Point(222.21127319335938, 393.9405517578125)),
#     ('c', Point(222.21127319335938, 393.9405517578125), Point(221.8440399169922, 394.0926818847656), Point(221.46170043945312, 394.1687316894531), Point(221.064208984375, 394.1687316894531)),
#     ('c', Point(221.064208984375, 394.1687316894531), Point(220.66668701171875, 394.1687316894531), Point(220.28431701660156, 394.0926818847656), Point(219.9171142578125, 393.9405517578125)),
#     ('c', Point(219.9171142578125, 393.9405517578125), Point(219.5498504638672, 393.7884216308594), Point(219.2257080078125, 393.5718078613281), Point(218.9446563720703, 393.2907409667969)),
#     ('c', Point(218.9446563720703, 393.2907409667969), Point(218.66358947753906, 393.0096435546875), Point(218.44699096679688, 392.68548583984375), Point(218.2948760986328, 392.3182678222656)),
#     ('c', Point(218.2948760986328, 392.3182678222656), Point(218.1427764892578, 391.9510498046875), Point(218.06671142578125, 391.5687255859375), Point(218.0667266845703, 391.1712646484375)),
#     ('c', Point(218.0667266845703, 391.1712646484375), Point(218.06671142578125, 390.77374267578125), Point(218.1427764892578, 390.3913879394531), Point(218.2948760986328, 390.0241394042969)),
#     ('c', Point(218.2948760986328, 390.0241394042969), Point(218.44699096679688, 389.65692138671875), Point(218.66358947753906, 389.332763671875), Point(218.9446563720703, 389.0517272949219)),
#     ('c', Point(218.9446563720703, 389.0517272949219), Point(219.2257080078125, 388.7706604003906), Point(219.5498504638672, 388.5540466308594), Point(219.9171142578125, 388.40191650390625)),
#     ('c', Point(219.9171142578125, 388.40191650390625), Point(220.28431701660156, 388.2498474121094), Point(220.66668701171875, 388.17376708984375), Point(221.064208984375, 388.17376708984375)),
#     ('c', Point(221.064208984375, 388.17376708984375), Point(221.46170043945312, 388.17376708984375), Point(221.8440399169922, 388.2498474121094), Point(222.21127319335938, 388.40191650390625)),
#     ('c', Point(222.21127319335938, 388.40191650390625), Point(222.57847595214844, 388.5540466308594), Point(222.90264892578125, 388.7706604003906), Point(223.18373107910156, 389.0517272949219)),
#     ('c', Point(223.18373107910156, 389.0517272949219), Point(223.4647979736328, 389.332763671875), Point(223.68138122558594, 389.65692138671875), Point(223.83351135253906, 390.0241394042969)),
#     ('c', Point(223.83351135253906, 390.0241394042969), Point(223.98561096191406, 390.3913879394531), Point(224.06167602539062, 390.77374267578125), Point(224.0616912841797, 391.1712646484375)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.06669999659061432, 0.06669999659061432, 0.06669999659061432)
#   rect: Rect(218.06671142578125, 388.17376708984375, 224.0616912841797, 394.1687316894531)
#   seqno: 84
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 21:
#   items: [
#     ('re', Rect(221.064208984375, 487.8399963378906, 221.81358337402344, 587.5062255859375), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.0, 0.0, 0.0)
#   rect: Rect(221.064208984375, 487.8399963378906, 221.81358337402344, 587.5062255859375)
#   seqno: 85
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 22:
#   items: [
#     ('re', Rect(236.80099487304688, 493.0856018066406, 313.9861145019531, 514.0679931640625), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.27059999108314514, 0.34119999408721924, 0.40779998898506165)
#   rect: Rect(236.80099487304688, 493.0856018066406, 313.9861145019531, 514.0679931640625)
#   seqno: 86
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 23:
#   items: [
#     ('c', Point(243.54531860351562, 539.171875), Point(243.54530334472656, 539.4202880859375), Point(243.4977569580078, 539.6591796875), Point(243.40267944335938, 539.8887939453125)),
#     ('c', Point(243.40267944335938, 539.8887939453125), Point(243.3076171875, 540.1182861328125), Point(243.1722412109375, 540.3209228515625), Point(242.99658203125, 540.49658203125)),
#     ('c', Point(242.99658203125, 540.49658203125), Point(242.8209228515625, 540.6722412109375), Point(242.6183319091797, 540.8076171875), Point(242.38880920410156, 540.9026489257812)),
#     ('c', Point(242.38880920410156, 540.9026489257812), Point(242.15927124023438, 540.9977416992188), Point(241.92031860351562, 541.0452270507812), Point(241.67189025878906, 541.0452880859375)),
#     ('c', Point(241.67189025878906, 541.0452880859375), Point(241.42344665527344, 541.0452270507812), Point(241.18446350097656, 540.9977416992188), Point(240.95492553710938, 540.9026489257812)),
#     ('c', Point(240.95492553710938, 540.9026489257812), Point(240.7254180908203, 540.8076171875), Point(240.5228271484375, 540.6722412109375), Point(240.34716796875, 540.49658203125)),
#     ('c', Point(240.34716796875, 540.49658203125), Point(240.17147827148438, 540.3209228515625), Point(240.03610229492188, 540.1182861328125), Point(239.9410400390625, 539.8887939453125)),
#     ('c', Point(239.9410400390625, 539.8887939453125), Point(239.84596252441406, 539.6591796875), Point(239.79844665527344, 539.4202880859375), Point(239.7984619140625, 539.171875)),
#     ('c', Point(239.7984619140625, 539.171875), Point(239.79844665527344, 538.9234008789062), Point(239.84596252441406, 538.6844482421875), Point(239.9410400390625, 538.4548950195312)),
#     ('c', Point(239.9410400390625, 538.4548950195312), Point(240.03610229492188, 538.225341796875), Point(240.17147827148438, 538.0228271484375), Point(240.34716796875, 537.84716796875)),
#     ('c', Point(240.34716796875, 537.84716796875), Point(240.5228271484375, 537.6714477539062), Point(240.7254180908203, 537.5360717773438), Point(240.95492553710938, 537.4410400390625)),
#     ('c', Point(240.95492553710938, 537.4410400390625), Point(241.18446350097656, 537.345947265625), Point(241.42344665527344, 537.2984619140625), Point(241.67189025878906, 537.2984619140625)),
# ...
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.06669999659061432, 0.06669999659061432, 0.06669999659061432)
#   rect: Rect(218.06671142578125, 499.08056640625, 224.0616912841797, 505.0755310058594)
#   seqno: 98
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 26:
#   items: [
#     ('re', Rect(221.064208984375, 640.7115478515625, 221.81358337402344, 714.1498413085938), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.0, 0.0, 0.0)
#   rect: Rect(221.064208984375, 640.7115478515625, 221.81358337402344, 714.1498413085938)
#   seqno: 99
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 27:
#   items: [
#     ('re', Rect(236.80099487304688, 645.9571533203125, 278.7657165527344, 666.9395141601562), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.27059999108314514, 0.34119999408721924, 0.40779998898506165)
#   rect: Rect(236.80099487304688, 645.9571533203125, 278.7657165527344, 666.9395141601562)
#   seqno: 100
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 28:
#   items: [
#     ('c', Point(243.54531860351562, 692.0433959960938), Point(243.54530334472656, 692.2918090820312), Point(243.4977569580078, 692.53076171875), Point(243.40267944335938, 692.7601928710938)),
#     ('c', Point(243.40267944335938, 692.7601928710938), Point(243.3076171875, 692.98974609375), Point(243.1722412109375, 693.1923828125), Point(242.99658203125, 693.3680419921875)),
#     ('c', Point(242.99658203125, 693.3680419921875), Point(242.8209228515625, 693.5436401367188), Point(242.6183319091797, 693.6790161132812), Point(242.38880920410156, 693.7741088867188)),
#     ('c', Point(242.38880920410156, 693.7741088867188), Point(242.15927124023438, 693.8692016601562), Point(241.92031860351562, 693.916748046875), Point(241.67189025878906, 693.9168090820312)),
#     ('c', Point(241.67189025878906, 693.9168090820312), Point(241.42344665527344, 693.916748046875), Point(241.18446350097656, 693.8692016601562), Point(240.95492553710938, 693.7741088867188)),
#     ('c', Point(240.95492553710938, 693.7741088867188), Point(240.7254180908203, 693.6790161132812), Point(240.5228271484375, 693.5436401367188), Point(240.34716796875, 693.3680419921875)),
#     ('c', Point(240.34716796875, 693.3680419921875), Point(240.17147827148438, 693.1923828125), Point(240.03610229492188, 692.98974609375), Point(239.9410400390625, 692.7601928710938)),
#     ('c', Point(239.9410400390625, 692.7601928710938), Point(239.84596252441406, 692.53076171875), Point(239.79844665527344, 692.2918090820312), Point(239.7984619140625, 692.0433959960938)),
#     ('c', Point(239.7984619140625, 692.0433959960938), Point(239.79844665527344, 691.794921875), Point(239.84596252441406, 691.5559692382812), Point(239.9410400390625, 691.326416015625)),
#     ('c', Point(239.9410400390625, 691.326416015625), Point(240.03610229492188, 691.096923828125), Point(240.17147827148438, 690.8943481445312), Point(240.34716796875, 690.7186279296875)),
#     ('c', Point(240.34716796875, 690.7186279296875), Point(240.5228271484375, 690.54296875), Point(240.7254180908203, 690.4075927734375), Point(240.95492553710938, 690.3125)),
#     ('c', Point(240.95492553710938, 690.3125), Point(241.18446350097656, 690.2174682617188), Point(241.42344665527344, 690.1699829101562), Point(241.67189025878906, 690.1699829101562)),
#     ('c', Point(241.67189025878906, 690.1699829101562), Point(241.92031860351562, 690.1699829101562), Point(242.15927124023438, 690.2174682617188), Point(242.38880920410156, 690.3125)),
#     ('c', Point(242.38880920410156, 690.3125), Point(242.6183319091797, 690.4075927734375), Point(242.8209228515625, 690.54296875), Point(242.99658203125, 690.7186279296875)),
#     ('c', Point(242.99658203125, 690.7186279296875), Point(243.1722412109375, 690.8943481445312), Point(243.3076171875, 691.096923828125), Point(243.40267944335938, 691.3263549804688)),
#     ('c', Point(243.40267944335938, 691.3263549804688), Point(243.4977569580078, 691.555908203125), Point(243.54530334472656, 691.794921875), Point(243.54531860351562, 692.0433959960938)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.26669999957084656, 0.26669999957084656, 0.26669999957084656)
#   rect: Rect(239.79844665527344, 690.1699829101562, 243.54531860351562, 693.9168090820312)
#   seqno: 105
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 29:
#   items: [
#     ('c', Point(224.0616912841797, 654.9495849609375), Point(224.06167602539062, 655.3470458984375), Point(223.98561096191406, 655.7293701171875), Point(223.83351135253906, 656.0965576171875)),
#     ('c', Point(223.83351135253906, 656.0965576171875), Point(223.68138122558594, 656.4638061523438), Point(223.4647979736328, 656.7880249023438), Point(223.18373107910156, 657.069091796875)),
#     ('c', Point(223.18373107910156, 657.069091796875), Point(222.90264892578125, 657.35009765625), Point(222.57847595214844, 657.5667114257812), Point(222.21127319335938, 657.71875)),
#     ('c', Point(222.21127319335938, 657.71875), Point(221.8440399169922, 657.8709716796875), Point(221.46170043945312, 657.947021484375), Point(221.064208984375, 657.947021484375)),
#     ('c', Point(221.064208984375, 657.947021484375), Point(220.66668701171875, 657.947021484375), Point(220.28431701660156, 657.8709716796875), Point(219.9171142578125, 657.7188110351562)),
#     ('c', Point(219.9171142578125, 657.7188110351562), Point(219.5498504638672, 657.5667114257812), Point(219.2257080078125, 657.35009765625), Point(218.9446563720703, 657.069091796875)),
#     ('c', Point(218.9446563720703, 657.069091796875), Point(218.66358947753906, 656.7880249023438), Point(218.44699096679688, 656.4638061523438), Point(218.2948760986328, 656.0965576171875)),
#     ('c', Point(218.2948760986328, 656.0965576171875), Point(218.1427764892578, 655.7293701171875), Point(218.06671142578125, 655.3470458984375), Point(218.0667266845703, 654.9495849609375)),
#     ('c', Point(218.0667266845703, 654.9495849609375), Point(218.06671142578125, 654.5520629882812), Point(218.1427764892578, 654.1696166992188), Point(218.2948760986328, 653.8023681640625)),
#     ('c', Point(218.2948760986328, 653.8023681640625), Point(218.44699096679688, 653.4351196289062), Point(218.66358947753906, 653.1110229492188), Point(218.9446563720703, 652.8299560546875)),
#     ('c', Point(218.9446563720703, 652.8299560546875), Point(219.2257080078125, 652.5489501953125), Point(219.5498504638672, 652.3323364257812), Point(219.9171142578125, 652.18017578125)),
#     ('c', Point(219.9171142578125, 652.18017578125), Point(220.28431701660156, 652.028076171875), Point(220.66668701171875, 651.9520874023438), Point(221.064208984375, 651.9520874023438)),
#     ('c', Point(221.064208984375, 651.9520874023438), Point(221.46170043945312, 651.9520874023438), Point(221.8440399169922, 652.028076171875), Point(222.21127319335938, 652.1801147460938)),
#     ('c', Point(222.21127319335938, 652.1801147460938), Point(222.57847595214844, 652.3323364257812), Point(222.90264892578125, 652.5489501953125), Point(223.18373107910156, 652.8299560546875)),
#     ('c', Point(223.18373107910156, 652.8299560546875), Point(223.4647979736328, 653.1110229492188), Point(223.68138122558594, 653.4351196289062), Point(223.83351135253906, 653.8023681640625)),
#     ('c', Point(223.83351135253906, 653.8023681640625), Point(223.98561096191406, 654.1696166992188), Point(224.06167602539062, 654.5520629882812), Point(224.0616912841797, 654.9495849609375)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.06669999659061432, 0.06669999659061432, 0.06669999659061432)
#   rect: Rect(218.06671142578125, 651.9520874023438, 224.0616912841797, 657.947021484375)
#   seqno: 108
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 30:
#   items: [
#     ('re', Rect(221.064208984375, 714.1498413085938, 221.81358337402344, 793.5830688476562), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.0, 0.0, 0.0)
#   rect: Rect(221.064208984375, 714.1498413085938, 221.81358337402344, 793.5830688476562)
#   seqno: 109
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 31:
#   items: [
#     ('re', Rect(236.80099487304688, 725.390380859375, 313.9861145019531, 746.3727416992188), -1),
#   ]
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.27059999108314514, 0.34119999408721924, 0.40779998898506165)
#   rect: Rect(236.80099487304688, 725.390380859375, 313.9861145019531, 746.3727416992188)
#   seqno: 110
#   layer:
#   closePath: None
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 32:
#   items: [
#     ('c', Point(243.54531860351562, 771.4766235351562), Point(243.54530334472656, 771.7249755859375), Point(243.4977569580078, 771.9639282226562), Point(243.40267944335938, 772.1934204101562)),
#     ('c', Point(243.40267944335938, 772.1934204101562), Point(243.3076171875, 772.4229736328125), Point(243.1722412109375, 772.6255493164062), Point(242.99658203125, 772.8013305664062)),
#     ('c', Point(242.99658203125, 772.8013305664062), Point(242.8209228515625, 772.9769287109375), Point(242.6183319091797, 773.1123046875), Point(242.38880920410156, 773.2073364257812)),
#     ('c', Point(242.38880920410156, 773.2073364257812), Point(242.15927124023438, 773.3024291992188), Point(241.92031860351562, 773.3499755859375), Point(241.67189025878906, 773.3500366210938)),
#     ('c', Point(241.67189025878906, 773.3500366210938), Point(241.42344665527344, 773.3499755859375), Point(241.18446350097656, 773.3024291992188), Point(240.95492553710938, 773.2073364257812)),
#     ('c', Point(240.95492553710938, 773.2073364257812), Point(240.7254180908203, 773.1123046875), Point(240.5228271484375, 772.9769287109375), Point(240.34716796875, 772.8013305664062)),
#     ('c', Point(240.34716796875, 772.8013305664062), Point(240.17147827148438, 772.6255493164062), Point(240.03610229492188, 772.4229736328125), Point(239.9410400390625, 772.1934204101562)),
#     ('c', Point(239.9410400390625, 772.1934204101562), Point(239.84596252441406, 771.9639282226562), Point(239.79844665527344, 771.7249755859375), Point(239.7984619140625, 771.4766235351562)),
#     ('c', Point(239.7984619140625, 771.4766235351562), Point(239.79844665527344, 771.2280883789062), Point(239.84596252441406, 770.9891357421875), Point(239.9410400390625, 770.7596435546875)),
#     ('c', Point(239.9410400390625, 770.7596435546875), Point(240.03610229492188, 770.5301513671875), Point(240.17147827148438, 770.3275146484375), Point(240.34716796875, 770.15185546875)),
#     ('c', Point(240.34716796875, 770.15185546875), Point(240.5228271484375, 769.9761352539062), Point(240.7254180908203, 769.8407592773438), Point(240.95492553710938, 769.7457275390625)),
#     ('c', Point(240.95492553710938, 769.7457275390625), Point(241.18446350097656, 769.6506958007812), Point(241.42344665527344, 769.6032104492188), Point(241.67189025878906, 769.6032104492188)),
#     ('c', Point(241.67189025878906, 769.6032104492188), Point(241.92031860351562, 769.6032104492188), Point(242.15927124023438, 769.6506958007812), Point(242.38880920410156, 769.7457275390625)),
#     ('c', Point(242.38880920410156, 769.7457275390625), Point(242.6183319091797, 769.8407592773438), Point(242.8209228515625, 769.9761352539062), Point(242.99658203125, 770.15185546875)),
#     ('c', Point(242.99658203125, 770.15185546875), Point(243.1722412109375, 770.3275146484375), Point(243.3076171875, 770.5301513671875), Point(243.40267944335938, 770.7596435546875)),
#     ('c', Point(243.40267944335938, 770.7596435546875), Point(243.4977569580078, 770.9891357421875), Point(243.54530334472656, 771.2280883789062), Point(243.54531860351562, 771.4766235351562)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.26669999957084656, 0.26669999957084656, 0.26669999957084656)
#   rect: Rect(239.79844665527344, 769.6032104492188, 243.54531860351562, 773.3500366210938)
#   seqno: 116
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None
#
# Drawing 33:
#   items: [
#     ('c', Point(224.0616912841797, 734.3828125), Point(224.06167602539062, 734.7802124023438), Point(223.98561096191406, 735.1625366210938), Point(223.83351135253906, 735.52978515625)),
#     ('c', Point(223.83351135253906, 735.52978515625), Point(223.68138122558594, 735.8970336914062), Point(223.4647979736328, 736.22119140625), Point(223.18373107910156, 736.5023193359375)),
#     ('c', Point(223.18373107910156, 736.5023193359375), Point(222.90264892578125, 736.7833251953125), Point(222.57847595214844, 736.9998779296875), Point(222.21127319335938, 737.1520385742188)),
#     ('c', Point(222.21127319335938, 737.1520385742188), Point(221.8440399169922, 737.3041381835938), Point(221.46170043945312, 737.3802490234375), Point(221.064208984375, 737.3803100585938)),
#     ('c', Point(221.064208984375, 737.3803100585938), Point(220.66668701171875, 737.3802490234375), Point(220.28431701660156, 737.3041381835938), Point(219.9171142578125, 737.1520385742188)),
#     ('c', Point(219.9171142578125, 737.1520385742188), Point(219.5498504638672, 736.9998779296875), Point(219.2257080078125, 736.7833251953125), Point(218.9446563720703, 736.5023193359375)),
#     ('c', Point(218.9446563720703, 736.5023193359375), Point(218.66358947753906, 736.22119140625), Point(218.44699096679688, 735.8970336914062), Point(218.2948760986328, 735.5298461914062)),
#     ('c', Point(218.2948760986328, 735.5298461914062), Point(218.1427764892578, 735.16259765625), Point(218.06671142578125, 734.7802124023438), Point(218.0667266845703, 734.3828125)),
#     ('c', Point(218.0667266845703, 734.3828125), Point(218.06671142578125, 733.9852294921875), Point(218.1427764892578, 733.6028442382812), Point(218.2948760986328, 733.235595703125)),
#     ('c', Point(218.2948760986328, 733.235595703125), Point(218.44699096679688, 732.868408203125), Point(218.66358947753906, 732.5443115234375), Point(218.9446563720703, 732.2632446289062)),
#     ('c', Point(218.9446563720703, 732.2632446289062), Point(219.2257080078125, 731.9821166992188), Point(219.5498504638672, 731.7655029296875), Point(219.9171142578125, 731.6134033203125)),
#     ('c', Point(219.9171142578125, 731.6134033203125), Point(220.28431701660156, 731.4613647460938), Point(220.66668701171875, 731.3853149414062), Point(221.064208984375, 731.3853149414062)),
#     ('c', Point(221.064208984375, 731.3853149414062), Point(221.46170043945312, 731.3853149414062), Point(221.8440399169922, 731.4613647460938), Point(222.21127319335938, 731.6134033203125)),
#     ('c', Point(222.21127319335938, 731.6134033203125), Point(222.57847595214844, 731.7655029296875), Point(222.90264892578125, 731.9821166992188), Point(223.18373107910156, 732.2632446289062)),
#     ('c', Point(223.18373107910156, 732.2632446289062), Point(223.4647979736328, 732.5443115234375), Point(223.68138122558594, 732.868408203125), Point(223.83351135253906, 733.235595703125)),
#     ('c', Point(223.83351135253906, 733.235595703125), Point(223.98561096191406, 733.6028442382812), Point(224.06167602539062, 733.9852294921875), Point(224.0616912841797, 734.3828125)),
#   ]
#   closePath: True
#   type: f
#   even_odd: False
#   fill_opacity: 1.0
#   fill: (0.06669999659061432, 0.06669999659061432, 0.06669999659061432)
#   rect: Rect(218.06671142578125, 731.3853149414062, 224.0616912841797, 737.3803100585938)
#   seqno: 119
#   layer:
#   color: None
#   width: None
#   lineCap: None
#   lineJoin: None
#   dashes: None
#   stroke_opacity: None

# %%
# Example function to clean OCR text
def clean_text(raw_text):
    # Implement text cleaning here. This could include removing whitespace, correcting OCR mistakes, etc.
    cleaned_text = raw_text.strip()  # This is a placeholder, adapt as needed.
    return cleaned_text

# Clean the extracted texts
cleaned_image_text = clean_text(image_text)
cleaned_pdf_texts = [clean_text(text) for text in pdf_texts]

# %%
def convert_point(point):
    return (point.x, point.y)

def convert_shape(item):
    action, *args = item
    converted_args = []
    for arg in args:
        if isinstance(arg, fitz.Rect):
            converted_args.append((arg.x0, arg.y0, arg.x1, arg.y1))
        elif isinstance(arg, fitz.Point):
            converted_args.append((arg.x, arg.y))
        else:
            converted_args.append(arg)
    return (action, *converted_args)

def convert_drawings(drawings):
    serializable_drawings = []
    for drawing in drawings:
        converted = {k: (v if not isinstance(v, (fitz.Rect, fitz.Point)) else
                         (v.x0, v.y0, v.x1, v.y1) if isinstance(v, fitz.Rect) else
                         (v.x, v.y)) for k, v in drawing.items()}
        
        # Convert the items list
        converted_items = [convert_shape(item) for item in drawing.get('items', [])]
        converted['items'] = converted_items
        serializable_drawings.append(converted)
    return serializable_drawings

# Apply conversion to all pages' drawings in pdf_visuals
for page_visual in pdf_visuals:
    page_visual['drawings'] = convert_drawings(page_visual['drawings'])

# %%
import json

# Combine all extracted data into a dictionary
extracted_data = {
    'image_text': cleaned_image_text,
    'pdf_texts': cleaned_pdf_texts,
    'pdf_visuals': pdf_visuals
}

# Convert dictionary to JSON and save to a file
with open('extracted_data_raw.json', 'w') as json_file:
    json.dump(extracted_data, json_file, indent=4)

# %%
import json

# Function to convert complex JSON drawing details into a more readable format
def convert_to_readable_format(data):
    readable_data = []
    
    for page in data['pdf_visuals']:
        page_data = {
            'page_images': len(page['images']),
            'drawings': []
        }
        
        for drawing in page['drawings']:
            
            
            # Determine the type and coordinates from items
            for item in drawing['items']:
                drawing_data = {
                'type': 'Unknown',  # Default type, will change based on actual data
                'coordinates': [],
                'properties': {}
            }
                if item[0] == 're':
                    drawing_data['type'] = 'Rectangle'
                    x, y, w, h = item[1]
                    drawing_data['coordinates'] = {'x': x, 'y': y, 'width': w, 'height': h}
                elif item[0] == 'l':
                    # print(item)
                    drawing_data['type'] = 'Line'
                    drawing_data['coordinates'] = {'start': {'x': item[1][0], 'y': item[1][1]}, 'end': {'x': item[2][0], 'y': item[2][1]}}
                    # print(item)
                elif item[0] == 'c':
                    drawing_data['type'] = 'Curve'
                    drawing_data['coordinates'] = {'points': item[1:]}
                # Add more shapes as needed
            
                
                    
                # Add other properties
                drawing_data['properties'] = {
                    'fill_color': drawing.get('fill', 'None'),
                    'fill_opacity': drawing.get('fill_opacity', 'None'),
                    'stroke_color': drawing.get('color', 'None'),
                    'stroke_opacity': drawing.get('stroke_opacity', 'None'),
                    # Add more properties as needed
                }
                

                
                page_data['drawings'].append(drawing_data)
            
        readable_data.append(page_data)
    
    return readable_data



# Load the actual JSON data from the provided file and then convert it using the defined function
with open("extracted_data_raw.json", 'r') as file:
    actual_data = json.load(file)

# Use the previously defined function to convert this actual data
readable_actual_data = convert_to_readable_format(actual_data)

with open('extracted_data_readable.json', 'w') as outfile:
    json.dump(readable_actual_data, outfile, indent=4)

# %%
import json

def update_readable_format(data):
    updated_data = []
    for page in data:
        updated_drawings = []
        for drawing in page['drawings']:
            updated_drawing = {}
            updated_drawing['type'] = drawing['type']
            
            # Update the coordinates to be more descriptive
            if drawing['type'] in ['Rectangle', 'Line']:
                updated_drawing['coordinates'] = drawing['coordinates']
            elif drawing['type'] == 'Curve':
                updated_drawing['coordinates'] = {'control_points': drawing['coordinates']['points']}
            
            # Convert RGB colors to hexadecimal
            updated_properties = drawing['properties']
            if updated_properties['fill_color']:
                r, g, b = [int(c * 255) for c in updated_properties['fill_color']]
                updated_properties['fill_color'] = f'#{r:02x}{g:02x}{b:02x}'
            if updated_properties.get('stroke_color'):
                r, g, b = [int(c * 255) for c in updated_properties.get('stroke_color', [0,0,0])]
                updated_properties['stroke_color'] = f'#{r:02x}{g:02x}{b:02x}'
            
            updated_drawing['properties'] = updated_properties
            updated_drawings.append(updated_drawing)
        
        updated_data.append({'page_images': page['page_images'], 'drawings': updated_drawings})

    return updated_data

# Assuming 'json_data' is your loaded JSON structure
with open('extracted_data_readable.json', 'r') as f:
    json_data = json.load(f)

updated_json_data = update_readable_format(json_data)

# Optionally, write the updated JSON back to a file
with open('extracted_data_final.json', 'w') as f:
    json.dump(updated_json_data, f, indent=4)
