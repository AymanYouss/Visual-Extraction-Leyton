# %%
from word_detector import prepare_img, detect, sort_line
import matplotlib.pyplot as plt
import cv2

# (1) prepare image:
# (1a) convert to grayscale
# (1b) scale to specified height because algorithm is not scale-invariant
img = prepare_img(cv2.imread('data/line/5.png'), 50)

# (2) detect words in image
detections = detect(img,
                    kernel_size=25,
                    sigma=11,
                    theta=7,
                    min_area=100)

# (3) sort words in line
line = sort_line(detections)[0]

# (4) show word images
plt.subplot(len(line), 1, 1)
plt.imshow(img, cmap='gray')
for i, word in enumerate(line):
  print(word.bbox)
  plt.subplot(len(line), 1, i + 2)
  plt.imshow(word.img, cmap='gray')
plt.show()
# Out:
# BBox(x=0, y=6, w=83, h=29)
# BBox(x=94, y=14, w=51, h=20)
# BBox(x=155, y=17, w=51, h=19)
# BBox(x=207, y=6, w=161, h=41)
# BBox(x=375, y=14, w=67, h=19)
# BBox(x=445, y=17, w=58, h=15)
# BBox(x=537, y=4, w=32, h=25)
# BBox(x=579, y=5, w=76, h=28)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 25
#      23 for i, word in enumerate(line):
#      24   print(word.bbox)
# ---> 25   plt.subplot(len(line), 1, i + 2)
#      26   plt.imshow(word.img, cmap='gray')
#      27 plt.show()
#
# File c:\Users\21269\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:1440, in subplot(*args, **kwargs)
#    1437 fig = gcf()
#    1439 # First, search for an existing subplot with a matching spec.
# -> 1440 key = SubplotSpec._from_subplot_args(fig, args)
#    1442 for ax in fig.axes:
#    1443     # If we found an Axes at the position, we can re-use it if the user passed no
#    1444     # kwargs or if the axes class and kwargs are identical.
#    1445     if (ax.get_subplotspec() == key
#    1446         and (kwargs == {}
#    1447              or (ax._projection_init
#    1448                  == fig._process_projection_requirements(**kwargs)))):
#
# File c:\Users\21269\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\gridspec.py:599, in SubplotSpec._from_subplot_args(figure, args)
#     597 else:
#     598     if not isinstance(num, Integral) or num < 1 or num > rows*cols:
# --> 599         raise ValueError(
#     600             f"num must be an integer with 1 <= num <= {rows*cols}, "
#     601             f"not {num!r}"
#     602         )
#     603     i = j = num
#     604 return gs[i-1:j]
#
# ValueError: num must be an integer with 1 <= num <= 8, not 9
